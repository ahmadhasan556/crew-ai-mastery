# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
  model = 'gemini/gemini-2.5-flash',
  temperature=0.1
)
llm.call("what is crew ai tell me in one line")
# Out:
# 'CrewAI is a framework for orchestrating collaborative AI agents to achieve specific goals.'

# %%
from crewai import Agent, Task, Crew
# first we specifiy the agent
email_assitant = Agent(
  role= "email_assistant",
  goal= "Improve emails and make them sound professional and clear",
  backstory="A highly experience communication expoer skilled in professinal email writing.",
  verbose = True,
  llm = llm
)
orignal_email = """hey teamm just wanted to tell you that the demo is kind of ready, but there's still stuff left. maybe we can show what we have and say rest wip what do you think?"""
# then we create a task for the agent to complete
email_task= Task(
  description=f"""Take the following rough email and improve it to make it sound more professional and clear: {orignal_email}""",
  agent=email_assitant,
  expected_output='A professionally written email that clearly communicates the status of the demo and next steps.'
)

# then we create a crew to complete the task
crew = Crew(
  agents=[email_assitant],
  tasks=[email_task],
  verbose = True
)
result = crew.kickoff()
print(result)
# Out:
# ┌───────────────────────── 🚀 Crew Execution Started ─────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 0bc240bb-eb64-4963-aa9a-a6bf269aafc6                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── 📋 Task Started ──────────────────────────────┐
# │                                                                             │
# │  Task Started                                                               │
# │  Name: Take the following rough email and improve it to make it sound more  │
# │  professional and clear: hey teamm just wanted to tell you that the demo    │
# │  is kind of ready, but there's still stuff left. maybe we can show what we  │
# │  have and say rest wip what do you think?                                   │
# │  ID: 7e17e7f7-56ec-40ee-a3e7-5c3f0e652468                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: email_assistant                                                     │
# │                                                                             │
# │  Task: Take the following rough email and improve it to make it sound more  │
# │  professional and clear: hey teamm just wanted to tell you that the demo    │
# │  is kind of ready, but there's still stuff left. maybe we can show what we  │
# │  have and say rest wip what do you think?                                   │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: email_assistant                                                     │
# │                                                                             │
# │  Final Answer:                                                              │
# │  Subject: Demo Status Update                                                │
# │                                                                             │
# │  Hi Team,                                                                   │
# │                                                                             │
# │  I'm writing to provide an update on the upcoming demo. The core            │
# │  functionality is largely complete and ready for review; however, there     │
# │  are a few minor elements still in progress.                                │
# │                                                                             │
# │  Given the current state, I propose we proceed with showcasing the          │
# │  completed sections and clearly communicate that the remaining items are    │
# │  actively being worked on and are considered work in progress.              │
# │                                                                             │
# │  Please let me know your thoughts on this approach.                         │
# │                                                                             │
# │  Best regards,                                                              │
# │                                                                             │
# │  [Your Name]                                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────── 📋 Task Completion ─────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: Take the following rough email and improve it to make it sound more  │
# │  professional and clear: hey teamm just wanted to tell you that the demo    │
# │  is kind of ready, but there's still stuff left. maybe we can show what we  │
# │  have and say rest wip what do you think?                                   │
# │  Agent: email_assistant                                                     │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 0bc240bb-eb64-4963-aa9a-a6bf269aafc6                                   │
# │  Final Output: Subject: Demo Status Update                                  │
# │                                                                             │
# │  Hi Team,                                                                   │
# │                                                                             │
# │  I'm writing to provide an update on the upcoming demo. The core            │
# │  functionality is largely complete and ready for review; however, there     │
# │  are a few minor elements still in progress.                                │
# │                                                                             │
# │  Given the current state, I propose we proceed with showcasing the          │
# │  completed sections and clearly communicate that the remaining items are    │
# │  actively being worked on and are considered work in progress.              │
# │                                                                             │
# │  Please let me know your thoughts on this approach.                         │
# │                                                                             │
# │  Best regards,                                                              │
# │                                                                             │
# │  [Your Name]                                                                │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Subject: Demo Status Update
#
# Hi Team,
#
# I'm writing to provide an update on the upcoming demo. The core functionality is largely complete and ready for review; however, there are a few minor elements still in progress.
#
# Given the current state, I propose we proceed with showcasing the completed sections and clearly communicate that the remaining items are actively being worked on and are considered work in progress.
#
# Please let me know your thoughts on this approach.
#
# Best regards,
#
# [Your Name]
