# %%
# configuration
from crewai import LLM
from dotenv import load_dotenv
load_dotenv()
llm = LLM(
  model = 'gemini/gemini-2.5-flash',
  temperature=0.1,
)
# print(llm)
llm.call("what is crew ai tell me in one line")
# Out:
# 'Crew AI is a framework that orchestrates collaborative AI agents to achieve complex goals.'

# %%
# creating agents
from crewai import Agent , Task , Crew 
from crewai_tools import SerperDevTool
research_agent = Agent(
  role = "Research Specialist",
  goal = "Research interesting facts about {topic} and summarize them in a concise manner.",
  backstory = "You are an expert researcher with a knack for finding and summarizing interesting information.",
  tools = [SerperDevTool()],
  verbose=True,
  llm=llm
)
writer_agent = Agent(
  role = "Creative Writer",
  goal = "Write a short blog summary using the research",
  backstory = "You are skilled at writing engaging and informative blog summaries.",
  verbose=True,
  llm=llm
)

# %%
#  creating tasks for agent
research_task = Task(
  description="Find 3-5 interesting recent facts about {topic} as of year 2026..",
  expected_output="a bullet list of 3-5 facts",
  agent=research_agent
)
writing_task = Task(
  description="Write a 100-word blog post summary about {topic} using the facts from the research task",
  expected_output="A blog post summary",
  agent=writer_agent,
  context=[research_task]
)

# %%
# crew creation
crew = Crew(
  agents=[research_agent, writer_agent],
  tasks=[research_task, writing_task],
  verbose=True
)
crew.kickoff(inputs={"topic": "qunatam computing"})
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.13.0                                                                                        │
# │  Latest version:  1.14.1                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 8db34c99-2b6b-4856-ae14-c5dbc362133d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting recent facts about qunatam computing as of year 2026..                              │
# │  ID: f38a5899-c546-488d-a505-d6e1ede9e8e5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting recent facts about qunatam computing as of year 2026..                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  I cannot provide facts as of the year 2026, as my knowledge cutoff is more recent than that. However, I can    │
# │  provide some interesting recent facts about quantum computing as of late 2023/early 2024:                      │
# │                                                                                                                 │
# │  *   **Advancements in Error Correction:** Researchers continue to make strides in quantum error correction, a  │
# │  critical hurdle for building stable and reliable quantum computers. Recent work has focused on developing      │
# │  more robust quantum bits (qubits) and improving methods to detect and correct errors that arise from the       │
# │  delicate nature of quantum states.                                                                             │
# │  *   **Increased Investment and Commercialization:** The quantum computing industry is seeing significant       │
# │  investment from governments and private companies. This is leading to a push towards commercialization, with   │
# │  more startups emerging and established tech giants like IBM, Google, and Microsoft continuing to pour          │
# │  resources into developing quantum hardware and software, aiming for practical applications in the near         │
# │  future.                                                                                                        │
# │  *   **Hybrid Quantum-Classical Algorithms:** A growing area of focus is the development of hybrid algorithms   │
# │  that combine the strengths of classical computers with the potential power of quantum processors. These        │
# │  algorithms are seen as a stepping stone to achieving quantum advantage on current noisy intermediate-scale     │
# │  quantum (NISQ) devices, particularly in fields like materials science and drug discovery.                      │
# │  *   **New Qubit Technologies Emerge:** While superconducting and trapped-ion qubits remain prominent,          │
# │  research into alternative qubit technologies is gaining momentum. This includes advancements in topological    │
# │  qubits, photonic qubits, and silicon-based qubits, each offering unique advantages and challenges in terms of  │
# │  scalability, coherence, and error rates.                                                                       │
# │  *   **Quantum Computing as a Service (QCaaS):** Cloud-based access to quantum computers is becoming more       │
# │  prevalent, allowing researchers and developers to experiment with quantum algorithms without needing to own    │
# │  expensive hardware. This "Quantum Computing as a Service" model is democratizing access to quantum resources   │
# │  and accelerating research and development in the field.                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting recent facts about qunatam computing as of year 2026..                              │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about qunatam computing using the facts from the research task        │
# │  ID: 038dc45d-fbbc-4f1e-a8bf-05d26d41f19c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about qunatam computing using the facts from the research task        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Quantum computing is rapidly advancing, with significant strides in error correction crucial for building      │
# │  stable systems. The industry is booming with increased investment and commercialization, as tech giants and    │
# │  startups push for practical applications. A key focus is hybrid quantum-classical algorithms, leveraging       │
# │  current noisy devices for fields like materials science and drug discovery. Beyond superconducting and         │
# │  trapped-ion qubits, new technologies like topological and photonic qubits are emerging. Furthermore, "Quantum  │
# │  Computing as a Service" (QCaaS) is democratizing access, allowing researchers worldwide to experiment with     │
# │  this transformative technology via the cloud, accelerating innovation and development.                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about qunatam computing using the facts from the research task        │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# CrewOutput(raw='Quantum computing is rapidly advancing, with significant strides in error correction crucial for building stable systems. The industry is booming with increased investment and commercialization, as tech giants and startups push for practical applications. A key focus is hybrid quantum-classical algorithms, leveraging current noisy devices for fields like materials science and drug discovery. Beyond superconducting and trapped-ion qubits, new technologies like topological and photonic qubits are emerging. Furthermore, "Quantum Computing as a Service" (QCaaS) is democratizing access, allowing researchers worldwide to experiment with this transformative technology via the cloud, accelerating innovation and development.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting recent facts about qunatam computing as of year 2026..', name='Find 3-5 interesting recent facts about qunatam computing as of year 2026..', expected_output='a bullet list of 3-5 facts', summary='Find 3-5 interesting recent facts about qunatam computing as of...', raw='I cannot provide facts as of the year 2026, as my knowledge cutoff is more recent than that. However, I can provide some interesting recent facts about quantum computing as of late 2023/early 2024:\n\n*   **Advancements in Error Correction:** Researchers continue to make strides in quantum error correction, a critical hurdle for building stable and reliable quantum computers. Recent work has focused on developing more robust quantum bits (qubits) and improving methods to detect and correct errors that arise from the delicate nature of quantum states.\n*   **Increased Investment and Commercialization:** The quantum computing industry is seeing significant investment from governments and private companies. This is leading to a push towards commercialization, with more startups emerging and established tech giants like IBM, Google, and Microsoft continuing to pour resources into developing quantum hardware and software, aiming for practical applications in the near future.\n*   **Hybrid Quantum-Classical Algorithms:** A growing area of focus is the development of hybrid algorithms that combine the strengths of classical computers with the potential power of quantum processors. These algorithms are seen as a stepping stone to achieving quantum advantage on current noisy intermediate-scale quantum (NISQ) devices, particularly in fields like materials science and drug discovery.\n*   **New Qubit Technologies Emerge:** While superconducting and trapped-ion qubits remain prominent, research into alternative qubit technologies is gaining momentum. This includes advancements in topological qubits, photonic qubits, and silicon-based qubits, each offering unique advantages and challenges in terms of scalability, coherence, and error rates.\n*   **Quantum Computing as a Service (QCaaS):** Cloud-based access to quantum computers is becoming more prevalent, allowing researchers and developers to experiment with quantum algorithms without needing to own expensive hardware. This "Quantum Computing as a Service" model is democratizing access to quantum resources and accelerating research and development in the field.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert researcher with a knack for finding and summarizing interesting information.\nYour personal goal is: Research interesting facts about qunatam computing and summarize them in a concise manner.'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting recent facts about qunatam computing as of year 2026..\n\nThis is the expected criteria for your final answer: a bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.'}, {'role': 'assistant', 'content': 'I cannot provide facts as of the year 2026, as my k ...
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 8db34c99-2b6b-4856-ae14-c5dbc362133d                                                                       │
# │  Final Output: Quantum computing is rapidly advancing, with significant strides in error correction crucial     │
# │  for building stable systems. The industry is booming with increased investment and commercialization, as tech  │
# │  giants and startups push for practical applications. A key focus is hybrid quantum-classical algorithms,       │
# │  leveraging current noisy devices for fields like materials science and drug discovery. Beyond superconducting  │
# │  and trapped-ion qubits, new technologies like topological and photonic qubits are emerging. Furthermore,       │
# │  "Quantum Computing as a Service" (QCaaS) is democratizing access, allowing researchers worldwide to            │
# │  experiment with this transformative technology via the cloud, accelerating innovation and development.         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
