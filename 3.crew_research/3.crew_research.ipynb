# %%
# configuration
from crewai import LLM
from dotenv import load_dotenv
load_dotenv()

llm = LLM(
  model = 'gemini/gemini-2.5-flash',
  temperature=0.1
)
# llm.call("what is crew ai tell me in one line")

# %%
# creating agents
from crewai import Agent , Task , Crew 

research_agent = Agent(
  role = "Research Specialist",
  goal = "Research interesting facts about {topic} and summarize them in a concise manner.",
  backstory = "You are an expert researcher with a knack for finding and summarizing interesting information.",
  verbose=True,
  llm=llm
)

writer_agent = Agent(
  role = "Creative Writer",
  goal = "Write a short blog summary using the research",
  backstory = "You are skilled at writing engaging and informative blog summaries.",
  verbose=True,
  llm=llm
)

# %%
#  creating tasks for agent
research_task = Task(
  description="Find 3-5 interesting facts about {topic}",
  expected_output="a bullet list of 3-5 facts",
  agent=research_agent
)
writing_task = Task(
  description="Write a 100-word blog post summary about {topic} using the facts from the research task",
  expected_output="A blog post summary",
  agent=writer_agent,
  context=[research_task]
)

# %%
# crew creation
crew = Crew(
  agents=[research_agent, writer_agent],
  tasks=[research_task, writing_task],
  verbose=True
)
crew.kickoff(inputs={"topic": "quantum physics"})
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.13.0                                                                                        │
# │  Latest version:  1.14.1                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 5e959462-b4f8-4f5b-bf1c-9ad30057b68f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting facts about quantum physics                                                         │
# │  ID: 6de6fdc1-0c20-44d3-8583-30cf76592a18                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting facts about quantum physics                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 3-5 interesting facts about quantum physics:                                                          │
# │                                                                                                                 │
# │  *   **Quantum Superposition:** A quantum particle can exist in multiple states or locations simultaneously     │
# │  until it is observed or measured. It's only upon measurement that it "collapses" into a single, definite       │
# │  state.                                                                                                         │
# │  *   **Quantum Entanglement:** Two or more quantum particles can become "entangled," meaning they are linked    │
# │  in such a way that the state of one instantly influences the state of the other, no matter how far apart they  │
# │  are. This phenomenon, dubbed "spooky action at a distance" by Einstein, has been experimentally verified.      │
# │  *   **Wave-Particle Duality:** All quantum particles, such as photons and electrons, exhibit properties of     │
# │  both waves and particles. Depending on how they are observed or measured, they can behave like a discrete      │
# │  particle or a spread-out wave.                                                                                 │
# │  *   **Quantum Tunneling:** Particles can "tunnel" through energy barriers even if they don't classically have  │
# │  enough energy to overcome them. It's like a ball rolling up a hill and appearing on the other side without     │
# │  having enough momentum to reach the top. This effect is crucial for processes like nuclear fusion in the sun   │
# │  and the operation of scanning tunneling microscopes.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting facts about quantum physics                                                         │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about quantum physics using the facts from the research task          │
# │  ID: 4a755475-8c53-4c4c-8f70-252d0d9b4ae8                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about quantum physics using the facts from the research task          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Dive into the mind-bending world of quantum physics, where reality operates on rules far stranger than our     │
# │  everyday experience. Imagine particles existing in multiple states simultaneously (superposition) until        │
# │  observed, then "collapsing" into a single reality. Even more astonishing, entangled particles can instantly    │
# │  influence each other, no matter the distance – a phenomenon Einstein called "spooky action." These tiny        │
# │  entities also defy simple definitions, exhibiting both wave and particle properties (wave-particle duality).   │
# │  Plus, particles can "tunnel" through energy barriers they shouldn't be able to cross, a crucial process for    │
# │  stars and modern technology. Quantum physics challenges our classical understanding, paving the way for        │
# │  revolutionary advancements.                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about quantum physics using the facts from the research task          │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 5e959462-b4f8-4f5b-bf1c-9ad30057b68f                                                                       │
# │  Final Output: Dive into the mind-bending world of quantum physics, where reality operates on rules far         │
# │  stranger than our everyday experience. Imagine particles existing in multiple states simultaneously            │
# │  (superposition) until observed, then "collapsing" into a single reality. Even more astonishing, entangled      │
# │  particles can instantly influence each other, no matter the distance – a phenomenon Einstein called "spooky    │
# │  action." These tiny entities also defy simple definitions, exhibiting both wave and particle properties        │
# │  (wave-particle duality). Plus, particles can "tunnel" through energy barriers they shouldn't be able to        │
# │  cross, a crucial process for stars and modern technology. Quantum physics challenges our classical             │
# │  understanding, paving the way for revolutionary advancements.                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# CrewOutput(raw='Dive into the mind-bending world of quantum physics, where reality operates on rules far stranger than our everyday experience. Imagine particles existing in multiple states simultaneously (superposition) until observed, then "collapsing" into a single reality. Even more astonishing, entangled particles can instantly influence each other, no matter the distance – a phenomenon Einstein called "spooky action." These tiny entities also defy simple definitions, exhibiting both wave and particle properties (wave-particle duality). Plus, particles can "tunnel" through energy barriers they shouldn\'t be able to cross, a crucial process for stars and modern technology. Quantum physics challenges our classical understanding, paving the way for revolutionary advancements.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting facts about quantum physics', name='Find 3-5 interesting facts about quantum physics', expected_output='a bullet list of 3-5 facts', summary='Find 3-5 interesting facts about quantum physics...', raw='Here are 3-5 interesting facts about quantum physics:\n\n*   **Quantum Superposition:** A quantum particle can exist in multiple states or locations simultaneously until it is observed or measured. It\'s only upon measurement that it "collapses" into a single, definite state.\n*   **Quantum Entanglement:** Two or more quantum particles can become "entangled," meaning they are linked in such a way that the state of one instantly influences the state of the other, no matter how far apart they are. This phenomenon, dubbed "spooky action at a distance" by Einstein, has been experimentally verified.\n*   **Wave-Particle Duality:** All quantum particles, such as photons and electrons, exhibit properties of both waves and particles. Depending on how they are observed or measured, they can behave like a discrete particle or a spread-out wave.\n*   **Quantum Tunneling:** Particles can "tunnel" through energy barriers even if they don\'t classically have enough energy to overcome them. It\'s like a ball rolling up a hill and appearing on the other side without having enough momentum to reach the top. This effect is crucial for processes like nuclear fusion in the sun and the operation of scanning tunneling microscopes.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert researcher with a knack for finding and summarizing interesting information.\nYour personal goal is: Research interesting facts about quantum physics and summarize them in a concise manner.'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting facts about quantum physics\n\nThis is the expected criteria for your final answer: a bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': 'Here are 3-5 interesting facts about quantum physics:\n\n*   **Quantum Superposition:** A quantum particle can exist in multiple states or locations simultaneously until it is observed or measured. It\'s only upon measurement that it "collapses" into a single, definite state.\n*   **Quantum Entanglement:** Two or more quantum particles can become "entangled," meaning they are linked in such a way that the state of one instantly influences the state of the other, no matter how far apart they are. This phenomenon, dubbed "spooky action at a distance" by Einstein, has been experimentally verified.\n*   **Wave-Particle Duality:** All quantum particles, such as photons and electrons, exhibit properties of both waves and particles. Depending on how they are observed or measured, they can behave like a discrete particle or a spread-out wave.\n*   **Quantum Tunneling:** Particles can "tunnel" through energy barriers even if they don\'t classically have enough energy to ...
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
