# %%
# configuration
from crewai import LLM
from dotenv import load_dotenv
load_dotenv()

llm = LLM(
  model = 'gemini/gemini-2.5-flash',
  temperature=0.1
)
# llm.call("what is crew ai tell me in one line")

# %%
# creating agents
from crewai import Agent , Task , Crew 

research_agent = Agent(
  role = "Research Specialist",
  goal = "Research interesting facts about {topic} and summarize them in a concise manner.",
  backstory = "You are an expert researcher with a knack for finding and summarizing interesting information.",
  verbose=True,
  llm=llm
)
writer_agent = Agent(
  role = "Creative Writer",
  goal = "Write a short blog summary using the research",
  backstory = "You are skilled at writing engaging and informative blog summaries.",
  verbose=True,
  llm=llm
)

# %%
#  creating tasks for agent
research_task = Task(
  description="Find 3-5 interesting facts about {topic}",
  expected_output="a bullet list of 3-5 facts",
  agent=research_agent
)
writing_task = Task(
  description="Write a 100-word blog post summary about {topic} using the facts from the research task",
  expected_output="A blog post summary",
  agent=writer_agent,
  context=[research_task]
)

# %%
# crew creation
crew = Crew(
  agents=[research_agent, writer_agent],
  tasks=[research_task, writing_task],
  verbose=True
)
crew.kickoff(inputs={"topic": "quantum physics"})
# Out:
# ┌───────────────────────── 🚀 Crew Execution Started ─────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: fc229b43-7b8c-4ca1-84fe-2430c82e7dfb                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── 📋 Task Started ──────────────────────────────┐
# │                                                                             │
# │  Task Started                                                               │
# │  Name: Find 3-5 interesting facts about quantum physics                     │
# │  ID: 22d8cd6a-1682-4124-bf1d-075279c918f3                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Research Specialist                                                 │
# │                                                                             │
# │  Task: Find 3-5 interesting facts about quantum physics                     │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Research Specialist                                                 │
# │                                                                             │
# │  Final Answer:                                                              │
# │  Here are 3-5 interesting facts about quantum physics:                      │
# │                                                                             │
# │  *   **Quantum Superposition:** A quantum particle can exist in multiple    │
# │  states (e.g., spin up and spin down, or in two places at once)             │
# │  simultaneously until it is measured. It's only upon observation that it    │
# │  "collapses" into a single definite state.                                  │
# │  *   **Quantum Entanglement:** Two or more quantum particles can become     │
# │  linked in such a way that they share the same fate, no matter how far      │
# │  apart they are. Measuring the state of one instantly influences the state  │
# │  of the other, even if they are light-years apart, a phenomenon Albert      │
# │  Einstein famously called "spooky action at a distance."                    │
# │  *   **Wave-Particle Duality:** All quantum particles (like electrons and   │
# │  photons) exhibit properties of both waves and particles. Depending on how  │
# │  you observe them, they can behave like a localized particle or a           │
# │  spread-out wave.                                                           │
# │  *   **Quantum Tunneling:** Particles can sometimes "tunnel" through        │
# │  energy barriers that they classically shouldn't have enough energy to      │
# │  overcome. It's like a ball rolling up a hill, but instead of rolling over  │
# │  the top, it sometimes just appears on the other side without having        │
# │  enough energy to clear it. This phenomenon is crucial for processes like   │
# │  nuclear fusion in the sun and the operation of scanning tunneling          │
# │  microscopes.                                                               │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────── 📋 Task Completion ─────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: Find 3-5 interesting facts about quantum physics                     │
# │  Agent: Research Specialist                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── 📋 Task Started ──────────────────────────────┐
# │                                                                             │
# │  Task Started                                                               │
# │  Name: Write a 100-word blog post summary about quantum physics using the   │
# │  facts from the research task                                               │
# │  ID: b932c1e3-7f50-4694-9668-5c767b02c690                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Creative Writer                                                     │
# │                                                                             │
# │  Task: Write a 100-word blog post summary about quantum physics using the   │
# │  facts from the research task                                               │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Creative Writer                                                     │
# │                                                                             │
# │  Final Answer:                                                              │
# │  Dive into the mind-bending world of quantum physics, where reality         │
# │  operates on entirely different rules! Imagine particles existing in        │
# │  multiple states at once until observed – that's **quantum                  │
# │  superposition**. Then there's **entanglement**, where two particles        │
# │  become mysteriously linked, instantly influencing each other no matter     │
# │  the distance, a phenomenon Einstein called "spooky action." Prepare to be  │
# │  amazed by **wave-particle duality**, revealing that particles can behave   │
# │  as both waves and discrete particles depending on how you look. And        │
# │  perhaps most bizarre is **quantum tunneling**, allowing particles to       │
# │  magically pass through energy barriers they classically shouldn't          │
# │  overcome, powering stars and cutting-edge technology. It's a universe of   │
# │  probabilities and profound strangeness!                                    │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────── 📋 Task Completion ─────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: Write a 100-word blog post summary about quantum physics using the   │
# │  facts from the research task                                               │
# │  Agent: Creative Writer                                                     │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: fc229b43-7b8c-4ca1-84fe-2430c82e7dfb                                   │
# │  Final Output: Dive into the mind-bending world of quantum physics, where   │
# │  reality operates on entirely different rules! Imagine particles existing   │
# │  in multiple states at once until observed – that's **quantum               │
# │  superposition**. Then there's **entanglement**, where two particles        │
# │  become mysteriously linked, instantly influencing each other no matter     │
# │  the distance, a phenomenon Einstein called "spooky action." Prepare to be  │
# │  amazed by **wave-particle duality**, revealing that particles can behave   │
# │  as both waves and discrete particles depending on how you look. And        │
# │  perhaps most bizarre is **quantum tunneling**, allowing particles to       │
# │  magically pass through energy barriers they classically shouldn't          │
# │  overcome, powering stars and cutting-edge technology. It's a universe of   │
# │  probabilities and profound strangeness!                                    │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# CrewOutput(raw='Dive into the mind-bending world of quantum physics, where reality operates on entirely different rules! Imagine particles existing in multiple states at once until observed – that\'s **quantum superposition**. Then there\'s **entanglement**, where two particles become mysteriously linked, instantly influencing each other no matter the distance, a phenomenon Einstein called "spooky action." Prepare to be amazed by **wave-particle duality**, revealing that particles can behave as both waves and discrete particles depending on how you look. And perhaps most bizarre is **quantum tunneling**, allowing particles to magically pass through energy barriers they classically shouldn\'t overcome, powering stars and cutting-edge technology. It\'s a universe of probabilities and profound strangeness!', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting facts about quantum physics', name='Find 3-5 interesting facts about quantum physics', expected_output='a bullet list of 3-5 facts', summary='Find 3-5 interesting facts about quantum physics...', raw='Here are 3-5 interesting facts about quantum physics:\n\n*   **Quantum Superposition:** A quantum particle can exist in multiple states (e.g., spin up and spin down, or in two places at once) simultaneously until it is measured. It\'s only upon observation that it "collapses" into a single definite state.\n*   **Quantum Entanglement:** Two or more quantum particles can become linked in such a way that they share the same fate, no matter how far apart they are. Measuring the state of one instantly influences the state of the other, even if they are light-years apart, a phenomenon Albert Einstein famously called "spooky action at a distance."\n*   **Wave-Particle Duality:** All quantum particles (like electrons and photons) exhibit properties of both waves and particles. Depending on how you observe them, they can behave like a localized particle or a spread-out wave.\n*   **Quantum Tunneling:** Particles can sometimes "tunnel" through energy barriers that they classically shouldn\'t have enough energy to overcome. It\'s like a ball rolling up a hill, but instead of rolling over the top, it sometimes just appears on the other side without having enough energy to clear it. This phenomenon is crucial for processes like nuclear fusion in the sun and the operation of scanning tunneling microscopes.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert researcher with a knack for finding and summarizing interesting information.\nYour personal goal is: Research interesting facts about quantum physics and summarize them in a concise manner.'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting facts about quantum physics\n\nThis is the expected criteria for your final answer: a bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': 'Here are 3-5 interesting facts about quantum physics:\n\n*   **Quantum Superposition:** A quantum particle can exist in multiple states (e.g., spin up and spin down, or in two places at once) simultaneously until it is measured. It\'s only upon observation that it "collapses" into a single definite state.\n*   **Quantum Entanglement:** Two or more quantum particles can become linked in such a way that they share the same fate, no matter how far apart they are. Measuring the state of one instantly influences the state of the other, even if they are light-years apart, a phenomenon Albert Einstein famously called "spooky action at a distance."\n*   **Wave-Particle Duality:** All quantum particles (like electrons and photons) exhibit properties of both waves and particles. Depending on how you observe them, they can behave like a localized particle or a sp ...
# ┌────────────────────────────── Tracing Status ───────────────────────────────┐
# │                                                                             │
# │  Info: Tracing is disabled.                                                 │
# │                                                                             │
# │  To enable tracing, do any one of these:                                    │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
